# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mt

# %%
df = pd.read_csv("tmdb-movies.csv")

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                                 homepage            director  \
# 0                          http://www.jurassicworld.com/     Colin Trevorrow
# 1                            http://www.madmaxmovie.com/       George Miller
# 2         http://www.thedivergentseries.movie/#insurgent    Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...         J.J. Abrams
# 4                               http://www.furious7.com/           James Wan
# ...                                                  ...                 ...
# 10861                                                NaN         Bruce Brown
# 10862                                                NaN  John Frankenheimer
# 10863                                                NaN      Eldar Ryazanov
# 10864                                                NaN         Woody Allen
# 10865                                                NaN    Harold P. Warren
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10861                                                NaN  ...
# 10862  Cinerama sweeps YOU into a drama of speed and ...  ...
# 10863                                                NaN  ...
# 10864                          WOODY ALLEN STRIKES BACK!  ...
# 10865       It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10861  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1      Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2      Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3              Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4      Universal Pictures|Original Film|Media Rights ...       4/1/15
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films      6/15/66
# 10862  Cherokee Productions|Joel Productions|Douglas ...     12/21/66
# 10863                                            Mosfilm       1/1/66
# 10864                            Benedict Pictures Corp.      11/2/66
# 10865                                          Norm-Iris     11/15/66
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10861         11           7.4          1966  0.000000e+00  0.000000e+00
# 10862         20           5.7          1966  0.000000e+00  0.000000e+00
# 10863         11           6.5          1966  0.000000e+00  0.000000e+00
# 10864         22           5.4          1966  0.000000e+00  0.000000e+00
# 10865         15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df = df[['budget','release_year','original_title','cast','genres','revenue','runtime']]

# %%
df
# Out:
#           budget  release_year                original_title  \
# 0      150000000          2015                Jurassic World
# 1      150000000          2015            Mad Max: Fury Road
# 2      110000000          2015                     Insurgent
# 3      200000000          2015  Star Wars: The Force Awakens
# 4      190000000          2015                     Furious 7
# ...          ...           ...                           ...
# 10861          0          1966            The Endless Summer
# 10862          0          1966                    Grand Prix
# 10863          0          1966           Beregis Avtomobilya
# 10864          0          1966        What's Up, Tiger Lily?
# 10865      19000          1966      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                           genres     revenue  runtime
# 0      Action|Adventure|Science Fiction|Thriller  1513528810      124
# 1      Action|Adventure|Science Fiction|Thriller   378436354      120
# 2             Adventure|Science Fiction|Thriller   295238201      119
# 3       Action|Adventure|Science Fiction|Fantasy  2068178225      136
# 4                          Action|Crime|Thriller  1506249360      137
# ...                                          ...         ...      ...
# 10861                                Documentary           0       95
# 10862                     Action|Adventure|Drama           0      176
# 10863                             Mystery|Comedy           0       94
# 10864                              Action|Comedy           0       80
# 10865                                     Horror           0       74
#
# [10866 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   budget          10866 non-null  int64
#  1   release_year    10866 non-null  int64
#  2   original_title  10866 non-null  object
#  3   cast            10790 non-null  object
#  4   genres          10843 non-null  object
#  5   revenue         10866 non-null  int64
#  6   runtime         10866 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 594.4+ KB

# %%
sorted_df_budget = df.sort_values(by = 'budget')

# %%
sorted_df_budget = sorted_df_budget[sorted_df_budget['budget']>10000]

# %%
sorted_df_budget[:50]
# Out:
#        budget  release_year                           original_title  \
# 4836    10400          2012                          Head Over Heels
# 7277    12000          1972                           Pink Flamingos
# 7447    15000          2007                      Paranormal Activity
# 6459    16398          2005            Star Wreck: In the Pirkinning
# 3785    17000          2011                               Bellflower
# 10865   19000          1966                 Manos: The Hands of Fate
# 3247    20000          2008                   Tomb Raider: Ascension
# 10538   22500          1986                               Mala Noche
# 9559    23000          1988               Hollywood Chainsaw Hookers
# 7781    25000          2007             In Search of a Midnight Kiss
# 2449    25000          1999                  The Blair Witch Project
# 9777    25000          1974                           Female Trouble
# 9623    25710          1987                                Bad Taste
# 4192    27000          1994                                   Clerks
# 2207    30000          2010                                  Catfish
# 9877    30000          1962                        Carnival of Souls
# 10160   30000          1960               The Little Shop of Horrors
# 2227    30000          2010                                     Howl
# 1871    31192          2009                             Down Terrace
# 9419    33000          1991                                 Begotten
# 8958    35000          1982                              Basket Case
# 4176    40000          2002             The Kid Stays in the Picture
# 10701   45000          1965            Faster, Pussycat! Kill! Kill!
# 3798    45202          2011                            Life in a Day
# 5878    50000          2013                    Jack the Giant Killer
# 7685    50000          2007                               The Signal
# 7185    50000          2004                               Eating Out
# 6486    50000          2005                      The Call of Cthulhu
# 9006    60000          1998                                       Pi
# 8923    60000          1982                                  Vincent
# 10673   60000          1970                       The Wizard of Gore
# 9763    60000          1974                                Dark Star
# 3895    61733          2011                                Blinkyâ„¢
# 8422    62000          1981                                   Ms .45
# 9869    62000          1962              The Brain That Wouldn't Die
# 2229    65000          2010                           Tiny Furniture
# 7178    65000          2004                            Super Size Me
# 10427   65000          1967                              Spider Baby
# 9922    65000          1964                    Two Thousand Maniacs!
# 10471   66500          1963                     La frusta e il corpo
# 10392   68000          1993                            Clean, Shaven
# 3736    70000          2011                                 Absentia
# 6483    72000          2005                           Shallow Ground
# 7166    74050          2004  The Heart is Deceitful Above All Things
# 10841   75000          1966                             The Shooting
# 7307    75000          1972                   Dr. Phibes Rises Again
# 6945    79000          2006                        The Foot Fist Way
# 9762    85000          1974             The Texas Chain Saw Massacre
# 10810   90000          1978           Attack of the Killer Tomatoes!
# 7280    90000          1972               The Last House on the Left
#
#                                                     cast  \
# 4836                    Nigel Anthony|Ruth Rayyah McCaul
# 7277   Divine|David Lochary|Mary Vivian Pearce|Mink S...
# 7447   Katie Featherston|Micah Sloat|Mark Fredrichs|A...
# 6459   Samuli Torssonen|Atte Joutsen|Timo Vuorensola|...
# 3785   Evan Glodell|Jessie Wiseman|Tyler Dawson|Rebek...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
# 3247   Anna Tyrie|Philip Goldacre|Peter Wear|Ava Hunt...
# 10538  Doug Cooeyate|Tim Streeter|Sam Downey|Nyla McC...
# 9559   Gunnar Hansen|Linnea Quigley|Jay Richardson|Mi...
# 7781           Scoot McNairy|Sara Simmonds|Brian McGuire
# 2449   Heather Donahue|Michael C. Williams|Joshua Leo...
# 9777   Divine|Mary Vivian Pearce|Mink Stole|Edith Mas...
# 9623   Terry Potter|Pete O'Herne|Craig Smith|Mike Min...
# 4192   Brian O'Halloran|Jeff Anderson|Jason Mewes|Kev...
# 2207   Megan Faccio|Melody C. Roscher|Ariel Schulman|...
# 9877   Candace Hilligoss|Frances Feist|Sidney Berger|...
# 10160  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 2227   James Franco|Jon Hamm|Mary-Louise Parker|Treat...
# 1871   Robert Hill|Robin Hill|Julia Deakin|David Scha...
# 9419   Brian Salzberg|Donna Dempsey|Stephen Charles B...
# 8958   Kevin Van Hentenryck|Terri Susan Smith|Beverly...
# 4176   Robert Evans|Eddie Albert|Francis Ford Coppola...
# 10701  Tura Satana|Haji|Lori Williams|Sue Bernard|Stu...
# 3798       Cindy Baer|Moica|Caryn Waechter|Drake Shannon
# 5878   Ben Cross|Jane March|Jamie Atkins|Vicki Glover...
# 7685   Anessa Ramsey|Justin Welborn|AJ Bowen|Scott Po...
# 7185   Rebekah Kochan|Ryan Carnes|Scott Lunsford|Jim ...
# 6486   Matt Foyer|John Bolen|Ralph Lucas|Chad Fifer|S...
# 9006   Sean Gullette|Mark Margolis|Ben Shenkman|Pamel...
# 8923                                       Vincent Price
# 10673  Ray Sager|Judy Cler|Wayne Ratay|Phil Laurenson...
# 9763   Brian Narelle|Cal Kuniholm|Dre Pahich|Adam Bec...
# 3895   Max Records|Jenni Fontana|James Nardini|Caroli...
# 8422   ZoÃ« Lund|Albert Sinkys|Darlene Stuto|Abel Fer...
# 9869   Jason Evers|Virginia Leith|Doris Brent|Audrey ...
# 2229   Lena Dunham|Laurie Simmons|Grace Dunham|Rachel...
# 7178   Morgan Spurlock|Daryl Isaacs|Lisa Ganjhu|Steph...
# 10427  Lon Chaney Jr.|Carol Ohmart|Quinn K. Redeker|B...
# 9922   Connie Mason|William Kerwin|Jeffrey Allen|Ben ...
# 10471  Daliah Lavi|Christopher Lee|Tony Kendall|Ida G...
# 10392  Peter Greene|Alice Levitt|Megan Owen|Jennifer ...
# 3736   Katie Parker|Courtney Bell|Morgan Peter Brown|...
# 6483   Timothy V. Murphy|Lindsey Stoddart|Rocky Marqu...
# 7166   Asia Argento|Jimmy Bennett|Jeremy Renner|Winon...
# 10841  Will Hutchins|Millie Perkins|Jack Nicholson|Wa...
# 7307   Vincent Price|Robert Quarry|Peter Cushing|Bery...
# 6945   Danny McBride|Ben Best|Mary Jane Bostic|Jody H...
# 9762   Allen Danziger|Paul A. Partain|William Vail|Te...
# 10810  David Miller|George Wilson|Sharon Taylor|J. St...
# 7280   Sandra Peabody|Lucy Grantham|David Hess|Fred J...
#
#                                        genres    revenue  runtime
# 4836          Family|Animation|Comedy|Romance          0       10
# 7277                                   Comedy    6000000       93
# 7447                           Horror|Mystery  193355800       86
# 6459            Science Fiction|Action|Comedy          0      103
# 3785                     Action|Drama|Romance     101236      106
# 10865                                  Horror          0       74
# 3247                           Action|Fantasy          0       60
# 10538                                   Drama          0       78
# 9559                            Comedy|Horror          0       75
# 7781                     Comedy|Drama|Romance          0       90
# 2449                           Horror|Mystery  248000000       81
# 9777                             Comedy|Crime          0       97
# 9623     Action|Comedy|Horror|Science Fiction          0       91
# 4192                                   Comedy    3151130       92
# 2207                              Documentary    3045943       87
# 9877                           Horror|Mystery          0       78
# 10160                                  Comedy          0       70
# 2227                                    Drama     617000       84
# 1871                      Drama|Action|Comedy      10000       89
# 9419                           Fantasy|Horror          0       78
# 8958                            Comedy|Horror          0       91
# 4176                              Documentary    1434436       93
# 10701                            Action|Crime          0       83
# 3798                        Documentary|Drama     225861       95
# 5878                           Action|Fantasy          0       87
# 7685   Horror|Action|Thriller|Science Fiction     249905      103
# 7185                                   Comedy          0       90
# 6486                  Horror|Thriller|Fantasy          0       47
# 9006                   Mystery|Drama|Thriller    3221152       84
# 8923                  Animation|Drama|Fantasy          0        6
# 10673                                  Horror          0       95
# 9763                   Comedy|Science Fiction          0       83
# 3895                   Science Fiction|Horror          0       13
# 8422              Horror|Crime|Drama|Thriller          0       81
# 9869                   Horror|Science Fiction          0       82
# 2229                                   Comedy          0       99
# 7178                 Documentary|Comedy|Drama   28575078      100
# 10427           Horror|Comedy|Science Fiction          0       81
# 9922                                   Horror          0       87
# 10471                          Mystery|Horror          0       87
# 10392                             Drama|Crime          0       79
# 3736                  Mystery|Horror|Thriller          0       92
# 6483                                   Horror          0       97
# 7166                                    Drama     176153       98
# 10841                                 Western          0       82
# 7307                            Comedy|Horror          0       89
# 6945                                   Comedy     245000       85
# 9762                          Horror|Thriller   30859000       83
# 10810           Comedy|Horror|Science Fiction          0       87
# 7280                          Horror|Thriller          0       84

# %% [markdown]
# # 1) Movies with the third lowest and third highest budget

# %%
sorted_df_budget.head()
# Out:
#       budget  release_year                 original_title  \
# 4836   10400          2012                Head Over Heels
# 7277   12000          1972                 Pink Flamingos
# 7447   15000          2007            Paranormal Activity
# 6459   16398          2005  Star Wreck: In the Pirkinning
# 3785   17000          2011                     Bellflower
#
#                                                    cast  \
# 4836                   Nigel Anthony|Ruth Rayyah McCaul
# 7277  Divine|David Lochary|Mary Vivian Pearce|Mink S...
# 7447  Katie Featherston|Micah Sloat|Mark Fredrichs|A...
# 6459  Samuli Torssonen|Atte Joutsen|Timo Vuorensola|...
# 3785  Evan Glodell|Jessie Wiseman|Tyler Dawson|Rebek...
#
#                                genres    revenue  runtime
# 4836  Family|Animation|Comedy|Romance          0       10
# 7277                           Comedy    6000000       93
# 7447                   Horror|Mystery  193355800       86
# 6459    Science Fiction|Action|Comedy          0      103
# 3785             Action|Drama|Romance     101236      106

# %%
sorted_df_budget.tail()
# Out:
#          budget  release_year                               original_title  \
# 6570  270000000          2006                             Superman Returns
# 14    280000000          2015                      Avengers: Age of Ultron
# 7387  300000000          2007     Pirates of the Caribbean: At World's End
# 3375  380000000          2011  Pirates of the Caribbean: On Stranger Tides
# 2244  425000000          2010                            The Warrior's Way
#
#                                                    cast  \
# 6570  Brandon Routh|Kevin Spacey|Kate Bosworth|James...
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...
# 3375  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
#
#                                          genres     revenue  runtime
# 6570   Adventure|Fantasy|Action|Science Fiction   391081192      154
# 14             Action|Adventure|Science Fiction  1405035767      141
# 7387                   Adventure|Fantasy|Action   961000000      169
# 3375                   Adventure|Action|Fantasy  1021683000      136
# 2244  Adventure|Fantasy|Action|Western|Thriller    11087569      100

# %% [markdown]
# # 4)Movies with most and least earned revenue

# %%
sorted_df_revenue = df.sort_values(by = 'revenue')

# %%
sorted_df_revenue.tail()
# Out:
#          budget  release_year                original_title  \
# 0     150000000          2015                Jurassic World
# 4361  220000000          2012                  The Avengers
# 5231  200000000          1997                       Titanic
# 3     200000000          2015  Star Wars: The Force Awakens
# 1386  237000000          2009                        Avatar
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 4361  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 5231  Kate Winslet|Leonardo DiCaprio|Frances Fisher|...
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
#
#                                          genres     revenue  runtime
# 0     Action|Adventure|Science Fiction|Thriller  1513528810      124
# 4361           Science Fiction|Action|Adventure  1519557910      143
# 5231                     Drama|Romance|Thriller  1845034188      194
# 3      Action|Adventure|Science Fiction|Fantasy  2068178225      136
# 1386   Action|Adventure|Fantasy|Science Fiction  2781505847      162

# %%
sorted_df_revenue['revenue'].value_counts()
# Out:
# 0             6016
# 12000000        10
# 10000000         8
# 11000000         7
# 2000000          6
#               ...
# 15368897         1
# 15309302         1
# 15304890         1
# 15240456         1
# 2781505847       1
# Name: revenue, Length: 4702, dtype: int64

# %%
sorted_df_revenue = sorted_df_revenue[sorted_df_revenue['revenue']>0]

# %%
sorted_df_revenue
# Out:
#           budget  release_year                  original_title  \
# 8142     6000000          1995                        Mallrats
# 5067     6000000          2003                 Shattered Glass
# 1380           0          1977                    The Sentinel
# 10607          0          1973                   Soylent Green
# 3239      200000          2008  Dr. Horrible's Sing-Along Blog
# ...          ...           ...                             ...
# 0      150000000          2015                  Jurassic World
# 4361   220000000          2012                    The Avengers
# 5231   200000000          1997                         Titanic
# 3      200000000          2015    Star Wars: The Force Awakens
# 1386   237000000          2009                          Avatar
#
#                                                     cast  \
# 8142   Jason Lee|Jeremy London|Shannen Doherty|Claire...
# 5067   Hayden Christensen|Peter Sarsgaard|ChloÃ« Sevi...
# 1380   Chris Sarandon|Cristina Raines|Martin Balsam|J...
# 10607  Charlton Heston|Edward G. Robinson|Leigh Taylo...
# 3239   Neil Patrick Harris|Nathan Fillion|Felicia Day...
# ...                                                  ...
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 4361   Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 5231   Kate Winslet|Leonardo DiCaprio|Frances Fisher|...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 1386   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
#
#                                               genres     revenue  runtime
# 8142                                  Romance|Comedy           2       94
# 5067                                   Drama|History           2       94
# 1380                            Horror|Drama|Mystery           3       92
# 10607               Mystery|Science Fiction|Thriller           3       97
# 3239   Adventure|Action|Comedy|Science Fiction|Music           3       42
# ...                                              ...         ...      ...
# 0          Action|Adventure|Science Fiction|Thriller  1513528810      124
# 4361                Science Fiction|Action|Adventure  1519557910      143
# 5231                          Drama|Romance|Thriller  1845034188      194
# 3           Action|Adventure|Science Fiction|Fantasy  2068178225      136
# 1386        Action|Adventure|Fantasy|Science Fiction  2781505847      162
#
# [4850 rows x 7 columns]

# %%
sorted_df_revenue.head()
# Out:
#         budget  release_year                  original_title  \
# 8142   6000000          1995                        Mallrats
# 5067   6000000          2003                 Shattered Glass
# 1380         0          1977                    The Sentinel
# 10607        0          1973                   Soylent Green
# 3239    200000          2008  Dr. Horrible's Sing-Along Blog
#
#                                                     cast  \
# 8142   Jason Lee|Jeremy London|Shannen Doherty|Claire...
# 5067   Hayden Christensen|Peter Sarsgaard|ChloÃ« Sevi...
# 1380   Chris Sarandon|Cristina Raines|Martin Balsam|J...
# 10607  Charlton Heston|Edward G. Robinson|Leigh Taylo...
# 3239   Neil Patrick Harris|Nathan Fillion|Felicia Day...
#
#                                               genres  revenue  runtime
# 8142                                  Romance|Comedy        2       94
# 5067                                   Drama|History        2       94
# 1380                            Horror|Drama|Mystery        3       92
# 10607               Mystery|Science Fiction|Thriller        3       97
# 3239   Adventure|Action|Comedy|Science Fiction|Music        3       42

# %% [markdown]
# # 5)Average runtime of movies in the year 2006

# %%
df_runtime = df[df['release_year']==2006]

# %%
df_runtime
# Out:
#          budget  release_year                              original_title  \
# 6554   50000000          2006                       Underworld: Evolution
# 6555  200000000          2006  Pirates of the Caribbean: Dead Man's Chest
# 6556  120000000          2006                                        Cars
# 6557  150000000          2006                               Casino Royale
# 6558  125000000          2006                           The Da Vinci Code
# ...         ...           ...                                         ...
# 6957          0          2006             Deutschland. Ein SommermÃ¤rchen
# 6958          0          2006                                        Hell
# 6959          0          2006                      How to Eat Fried Worms
# 6960    2700000          2006                                       ì§íŒ¨
# 6961          0          2006                           Khosla Ka Ghosla!
#
#                                                    cast  \
# 6554  Kate Beckinsale|Scott Speedman|Tony Curran|Sha...
# 6555  Johnny Depp|Orlando Bloom|Keira Knightley|Bill...
# 6556  Owen Wilson|Paul Newman|Bonnie Hunt|Larry the ...
# 6557  Daniel Craig|Eva Green|Mads Mikkelsen|Judi Den...
# 6558  Tom Hanks|Audrey Tautou|Ian McKellen|Paul Bett...
# ...                                                 ...
# 6957  Jens Lehmann|Arne Friedrich|Philipp Lahm|Torst...
# 6958  Nicolas Duvauchelle|Christiane Millet|Didier S...
# 6959  Luke Benward|Hallie Kate Eisenberg|Adam Hicks|...
# 6960  Ahn Jae-mo|Ahn Gil-kang|Jeong Seok-yong|Lee Be...
# 6961  Anupam Kher|Boman Irani|Parvin Dabas|Tara Shar...
#
#                                        genres     revenue  runtime
# 6554  Fantasy|Action|Science Fiction|Thriller   111340801      106
# 6555                 Adventure|Fantasy|Action  1065659812      151
# 6556        Animation|Adventure|Comedy|Family   461983149      117
# 6557                Adventure|Action|Thriller   599045960      144
# 6558                         Thriller|Mystery   758239851      149
# ...                                       ...         ...      ...
# 6957                              Documentary           0      107
# 6958                                    Drama           0      100
# 6959                      Comedy|Drama|Family    13022756       98
# 6960                          Action|Thriller           0       92
# 6961                                   Comedy           0      135
#
# [408 rows x 7 columns]

# %%
from math import *

# %%
df_runtime['runtime'].mean()
# Out:
# 101.68382352941177

# %% [markdown]
# # 2)Average number of words in movie titles between the year 2000-2005

# %%
df_title = df[(df['release_year']>1999) & (df['release_year']<2006)]

# %%
df_title
# Out:
#          budget  release_year  \
# 2633   93000000          2001
# 2634  125000000          2001
# 2635   15000000          2001
# 2636    6000000          2001
# 2637  115000000          2001
# ...         ...           ...
# 8883   15000000          2000
# 8884          0          2000
# 8885          0          2000
# 8886          0          2000
# 8887          0          2000
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# 2636                                       Donnie Darko
# 2637                                     Monsters, Inc.
# ...                                                 ...
# 8883                                       The In Crowd
# 8884                        Phir Bhi Dil Hai Hindustani
# 8885                                   The Tao of Steve
# 8886                                  George Washington
# 8887                                    Is It Fall Yet?
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# 2637  John Goodman|Billy Crystal|Mary Gibbs|Steve Bu...
# ...                                                 ...
# 8883  Susan Ward|Lori Heuring|Matthew Settle|Nathan ...
# 8884  Juhi Chawla|Shah Rukh Khan|Johnny Lever|Shakti...
# 8885  Donal Logue|Ayelet Kaznelson|John Hines|John H...
# 8886  Candace Evanofski|Donald Holden|Damian Jewan L...
# 8887                      Tracy Grandstaff|Wendy Hoopes
#
#                                genres    revenue  runtime
# 2633         Adventure|Fantasy|Action  871368364      178
# 2634         Adventure|Fantasy|Family  976475550      152
# 2635           Thriller|Drama|Mystery   20117339      147
# 2636            Fantasy|Drama|Mystery    1270522      113
# 2637  Fantasy|Animation|Family|Comedy  562816256       92
# ...                               ...        ...      ...
# 8883                         Thriller    5217498      105
# 8884             Romance|Comedy|Drama          0      168
# 8885                   Comedy|Romance          0       87
# 8886                            Drama          0       89
# 8887                 Animation|Comedy          0       75
#
# [1687 rows x 7 columns]

# %%
word_count = []
for i in range(df_title.shape[0]):
    current_title = str(df['original_title'].values[i])
    current_title_list = current_title.split(' ')
    n=0
    for each_word in current_title_list:
        n = n+1
    word_count.append(n)

# %%
average_list = sum(word_count) / len(word_count)

# %%
average_list
# Out:
# 2.784825133372851

# %% [markdown]
# # 3) Most common Genre for Vin Diesel & Emma Watson movies

# %%
df.dropna(axis="rows",how="any",subset=["cast"],inplace=True)
# Out:
# C:\Users\adish\AppData\Local\Temp\ipykernel_6196\3825581615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis="rows",how="any",subset=["cast"],inplace=True)

# %%
list_vin_diesel = []
list_emma_watson = []
for i in range(df.shape[0]):
    cast = str(df['cast'].values[i])
    cast_list = cast.split('|')
    for member in cast_list:
        if member == 'Vin Diesel':
            genre = str(df['genres'].values[i])
            genre_list = genre.split('|')
            for type in genre_list:
                list_vin_diesel.append(type)
        elif member == 'Emma Watson':
            genre = str(df['genres'].values[i])
            genre_list = genre.split('|')
            for type in genre_list:
                list_emma_watson.append(type)

# %%
df_vin_diesel = pd.DataFrame(list_vin_diesel, columns =['Genre'])
df_emma_watson = pd.DataFrame(list_emma_watson, columns =['Genre'])

# %%
df_vin_diesel.value_counts()
# Out:
# Genre
# Action             19
# Thriller           13
# Crime               8
# Science Fiction     8
# Drama               6
# Adventure           5
# Animation           3
# Comedy              2
# Family              2
# Fantasy             2
# dtype: int64

# %%
df_emma_watson.value_counts()
# Out:
# Genre
# Family       10
# Adventure     9
# Fantasy       8
# Drama         4
# Mystery       2
# Animation     1
# Comedy        1
# Crime         1
# Horror        1
# Romance       1
# Thriller      1
# dtype: int64

# %%
df
# Out:
#           budget  release_year                original_title  \
# 0      150000000          2015                Jurassic World
# 1      150000000          2015            Mad Max: Fury Road
# 2      110000000          2015                     Insurgent
# 3      200000000          2015  Star Wars: The Force Awakens
# 4      190000000          2015                     Furious 7
# ...          ...           ...                           ...
# 10861          0          1966            The Endless Summer
# 10862          0          1966                    Grand Prix
# 10863          0          1966           Beregis Avtomobilya
# 10864          0          1966        What's Up, Tiger Lily?
# 10865      19000          1966      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                           genres     revenue  runtime
# 0      Action|Adventure|Science Fiction|Thriller  1513528810      124
# 1      Action|Adventure|Science Fiction|Thriller   378436354      120
# 2             Adventure|Science Fiction|Thriller   295238201      119
# 3       Action|Adventure|Science Fiction|Fantasy  2068178225      136
# 4                          Action|Crime|Thriller  1506249360      137
# ...                                          ...         ...      ...
# 10861                                Documentary           0       95
# 10862                     Action|Adventure|Drama           0      176
# 10863                             Mystery|Comedy           0       94
# 10864                              Action|Comedy           0       80
# 10865                                     Horror           0       74
#
# [10790 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10790 entries, 0 to 10865
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   budget          10790 non-null  int64
#  1   release_year    10790 non-null  int64
#  2   original_title  10790 non-null  object
#  3   cast            10790 non-null  object
#  4   genres          10768 non-null  object
#  5   revenue         10790 non-null  int64
#  6   runtime         10790 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 674.4+ KB

# %%
n = 2068178225
df_thing = df[(df["revenue"]==int(n))]

# %%
df_thing
# Out:
#       budget  release_year original_title  \
# 2  110000000          2015      Insurgent
#
#                                                 cast  \
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                genres    revenue  runtime
# 2  Adventure|Science Fiction|Thriller  295238201      119

# %%
import csv
  
employee_info = ['emp_id', 'emp_name', 'skills']
  
new_dict = [
{'emp_id': 456, 'emp_name': 'George', 'skills': 'Python'},
{'emp_id': 892, 'emp_name': 'Adam', 'skills': 'Java'},
{'emp_id': 178, 'emp_name': 'Gilchrist', 'skills': 'Mongo db'},
{'emp_id': 155, 'emp_name': 'Elon', 'skills': 'Sql'},
{'emp_id': 299, 'emp_name': 'Mask', 'skills': 'Ruby'},
]
  
with open('test4.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames = employee_info)
    writer.writeheader()
    writer.writerows(new_dict)

# %%
import requests
import json
import pandas as pd
import csv
api_enpoint = 'https://api.mxtoolbox.com/api/v1/Lookup/dmarc/?argument=drvikramsethi.com&Authorization=1387afe2-f3a9-4475-b82e-39e8fde3d31e'
json_data = requests.get(api_enpoint).json()
#print(json_data)
warning = json_data.get('Warnings')
passed = json_data.get('Passed')
try:
    failed = json_data.get('Failed')
except:
    print('no fail')
    pass
report = ['name','info']
new_list = []
for w in warning:
    name = w.get('Name')
    info = w.get('Info')
    key = {'name':name, 'info':info}
    new_list.append(key)
print(new_list)
data = pd.DataFrame(new_list)  
print(data)  
csv_data = data.to_csv(path_of_buf='')  
print('\nCSV String Values:\n', csv_data)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=172'>173</a> try:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=173'>174</a>     conn = connection.create_connection(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=174'>175</a>         (self._dns_host, self.port), self.timeout, **extra_kw
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=175'>176</a>     )
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=177'>178</a> except SocketTimeout:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/connection.py?line=67'>68</a>     return six.raise_from(
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/connection.py?line=68'>69</a>         LocationParseError(u"'%s', label empty or too long" % host), None
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/connection.py?line=69'>70</a>     )
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/connection.py?line=71'>72</a> for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/connection.py?line=72'>73</a>     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/socket.py?line=953'>954</a> addrlist = []
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/socket.py?line=954'>955</a> for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/socket.py?line=955'>956</a>     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=704'>705</a>     method,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=705'>706</a>     url,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=706'>707</a>     timeout=timeout_obj,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=707'>708</a>     body=body,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=708'>709</a>     headers=headers,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=709'>710</a>     chunked=chunked,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=710'>711</a> )
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=712'>713</a> # If we're going to release the connection in ``finally:``, then
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=713'>714</a> # the response doesn't need to know about the connection. Otherwise
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=714'>715</a> # it will also try to release it and we'll have a double-release
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=715'>716</a> # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=384'>385</a> try:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=385'>386</a>     self._validate_conn(conn)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=386'>387</a> except (SocketTimeout, BaseSSLError) as e:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=387'>388</a>     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=1038'>1039</a> if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=1039'>1040</a>     conn.connect()
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=1041'>1042</a> if not conn.is_verified:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=355'>356</a> def connect(self):
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=356'>357</a>     # Add certificate verification
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=357'>358</a>     conn = self._new_conn()
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=358'>359</a>     hostname = self.host
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=184'>185</a> except SocketError as e:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=185'>186</a>     raise NewConnectionError(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=186'>187</a>         self, "Failed to establish a new connection: %s" % e
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=187'>188</a>     )
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connection.py?line=189'>190</a> return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000002B4CAF622F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=438'>439</a> if not chunked:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=439'>440</a>     resp = conn.urlopen(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=440'>441</a>         method=request.method,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=441'>442</a>         url=url,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=442'>443</a>         body=request.body,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=443'>444</a>         headers=request.headers,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=444'>445</a>         redirect=False,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=445'>446</a>         assert_same_host=False,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=446'>447</a>         preload_content=False,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=447'>448</a>         decode_content=False,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=448'>449</a>         retries=self.max_retries,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=449'>450</a>         timeout=timeout
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=450'>451</a>     )
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=452'>453</a> # Send the request.
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=453'>454</a> else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=782'>783</a>     e = ProtocolError("Connection aborted.", e)
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=784'>785</a> retries = retries.increment(
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=785'>786</a>     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=786'>787</a> )
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/connectionpool.py?line=787'>788</a> retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/retry.py?line=590'>591</a> if new_retry.is_exhausted():
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/retry.py?line=591'>592</a>     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/urllib3/util/retry.py?line=593'>594</a> log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.mxtoolbox.com', port=443): Max retries exceeded with url: /api/v1/Lookup/dmarc/?argument=drvikramsethi.com&Authorization=1387afe2-f3a9-4475-b82e-39e8fde3d31e (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002B4CAF622F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# c:\Users\adish\ML & py\Mini Project March ML Batch No 2.ipynb Cell 44' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/adish/ML%20%26%20py/Mini%20Project%20March%20ML%20Batch%20No%202.ipynb#ch0000043?line=3'>4</a> import csv
#       <a href='vscode-notebook-cell:/c%3A/Users/adish/ML%20%26%20py/Mini%20Project%20March%20ML%20Batch%20No%202.ipynb#ch0000043?line=4'>5</a> api_enpoint = 'https://api.mxtoolbox.com/api/v1/Lookup/dmarc/?argument=drvikramsethi.com&Authorization=1387afe2-f3a9-4475-b82e-39e8fde3d31e'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adish/ML%20%26%20py/Mini%20Project%20March%20ML%20Batch%20No%202.ipynb#ch0000043?line=5'>6</a> json_data = requests.get(api_enpoint).json()
#       <a href='vscode-notebook-cell:/c%3A/Users/adish/ML%20%26%20py/Mini%20Project%20March%20ML%20Batch%20No%202.ipynb#ch0000043?line=6'>7</a> #print(json_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/adish/ML%20%26%20py/Mini%20Project%20March%20ML%20Batch%20No%202.ipynb#ch0000043?line=7'>8</a> warning = json_data.get('Warnings')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=63'>64</a> def get(url, params=None, **kwargs):
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=64'>65</a>     r"""Sends a GET request.
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=65'>66</a>
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=66'>67</a>     :param url: URL for the new :class:`Request` object.
#    (...)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=71'>72</a>     :rtype: requests.Response
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=72'>73</a>     """
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=74'>75</a>     return request('get', url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=56'>57</a> # By using the 'with' statement we are sure the session is closed, thus we
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=57'>58</a> # avoid leaving sockets open which can trigger a ResourceWarning in some
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=58'>59</a> # cases, and look like a memory leak in others.
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=59'>60</a> with sessions.Session() as session:
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/api.py?line=60'>61</a>     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=523'>524</a> send_kwargs = {
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=524'>525</a>     'timeout': timeout,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=525'>526</a>     'allow_redirects': allow_redirects,
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=526'>527</a> }
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=527'>528</a> send_kwargs.update(settings)
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=528'>529</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=530'>531</a> return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=641'>642</a> start = preferred_clock()
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=643'>644</a> # Send the request
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=644'>645</a> r = adapter.send(request, **kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=646'>647</a> # Total elapsed time of the request (approximately)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/sessions.py?line=647'>648</a> elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=514'>515</a>     if isinstance(e.reason, _SSLError):
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=515'>516</a>         # This branch is for urllib3 v1.22 and later.
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=516'>517</a>         raise SSLError(e, request=request)
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=518'>519</a>     raise ConnectionError(e, request=request)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=520'>521</a> except ClosedPoolError as e:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/requests/adapters.py?line=521'>522</a>     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.mxtoolbox.com', port=443): Max retries exceeded with url: /api/v1/Lookup/dmarc/?argument=drvikramsethi.com&Authorization=1387afe2-f3a9-4475-b82e-39e8fde3d31e (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002B4CAF622F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
